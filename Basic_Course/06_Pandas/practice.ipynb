# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
agri=pd.read_csv("fao_data.csv")

# %%
agri.head(3)
# Out:
#   Domain Code                            Domain  Area Code (FAO)         Area  \
# 0          QV  Value of Agricultural Production                2  Afghanistan
# 1          QV  Value of Agricultural Production                2  Afghanistan
# 2          QV  Value of Agricultural Production                2  Afghanistan
#
#    Element Code                                        Element  \
# 0            56  Gross Production Value (current thousand SLC)
# 1            56  Gross Production Value (current thousand SLC)
# 2            56  Gross Production Value (current thousand SLC)
#
#    Item Code (FAO)                 Item  Year Code  Year      Unit    Value  \
# 0              221  Almonds, with shell       2002  2002  1000 SLC   883050
# 1              221  Almonds, with shell       2003  2003  1000 SLC  1246000
# 2              221  Almonds, with shell       2004  2004  1000 SLC  1337700
#
#   Flag Flag Description
# 0   Fc  Calculated data
# 1   Fc  Calculated data
# ...

# %%
agri.tail(2)
# Out:
#      Domain Code                            Domain  Area Code (FAO)  \
# 8281          QV  Value of Agricultural Production               38
# 8282          QV  Value of Agricultural Production               38
#
#            Area  Element Code                                        Element  \
# 8281  Sri Lanka            56  Gross Production Value (current thousand SLC)
# 8282  Sri Lanka            56  Gross Production Value (current thousand SLC)
#
#       Item Code (FAO)                   Item  Year Code  Year      Unit  \
# 8281              463  Vegetables, fresh nes       2019  2019  1000 SLC
# 8282              463  Vegetables, fresh nes       2020  2020  1000 SLC
#
#         Value Flag Flag Description
# 8281  3497272   Fc  Calculated data
# 8282  3244798   Fc  Calculated data

# %%
#basic statistics
agri.describe()
# Out:
#        Area Code (FAO)  Element Code  Item Code (FAO)    Year Code  \
# count      8283.000000        8283.0      8283.000000  8283.000000
# mean         82.176868          56.0       510.231438  2011.112037
# std          55.633280           0.0       322.853282     5.458588
# min           2.000000          56.0        15.000000  2002.000000
# 25%          18.000000          56.0       226.000000  2006.000000
# 50%         100.000000          56.0       490.000000  2011.000000
# 75%         132.000000          56.0       720.000000  2016.000000
# max         165.000000          56.0      1185.000000  2020.000000
#
#               Year         Value
# count  8283.000000  8.283000e+03
# mean   2011.112037  2.545387e+09
# std       5.458588  1.843007e+10
# min    2002.000000  2.200000e+01
# 25%    2006.000000  6.235260e+05
# 50%    2011.000000  5.662075e+06
# 75%    2016.000000  7.297441e+07
# max    2020.000000  4.608212e+11

# %%
#let's drop few columns and make a new dataset
agri_new= agri.drop(["Domain Code", "Area Code (FAO)", "Element Code", "Item Code (FAO)", "Year Code", "Flag", "Flag Description"], axis=1)
agri_new.head(2)
# Out:
#                              Domain         Area  \
# 0  Value of Agricultural Production  Afghanistan
# 1  Value of Agricultural Production  Afghanistan
#
#                                          Element                 Item  Year  \
# 0  Gross Production Value (current thousand SLC)  Almonds, with shell  2002
# 1  Gross Production Value (current thousand SLC)  Almonds, with shell  2003
#
#        Unit    Value
# 0  1000 SLC   883050
# 1  1000 SLC  1246000

# %%
#saving new dataframe
agri_new.to_csv("new_agri_data.csv")

# %%
#let's find means
agri_new.mean()
# Out:
# C:\Users\Ali Hamza\AppData\Local\Temp\ipykernel_12176\1885766340.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   agri_new.mean()
# Year     2.011112e+03
# Value    2.545387e+09
# dtype: float64

# %%
num_value=agri_new.value_counts("Value")
num_value.head()
# Out:
# Value
# 10800     8
# 401700    6
# 20160     4
# 16200     4
# 20400     3
# dtype: int64

# %%
agri_new.groupby(["Year", "Value", "Area", "Item"]).mean()
# Out:
# C:\Users\Ali Hamza\AppData\Local\Temp\ipykernel_12176\922706875.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   agri_new.groupby(["Year", "Value", "Area", "Item"]).mean()
# Empty DataFrame
# Columns: []
# ...

# %%
agri_new.dtypes
# Out:
# Domain     object
# Area       object
# Element    object
# Item       object
# Year        int64
# Unit       object
# Value       int64
# dtype: object

# %%
agri_new[agri_new["Year"]<2003].groupby(["Area", "Item"]).mean()
# Out:
#                                        Year      Value
# Area        Item
# Afghanistan Almonds, with shell      2002.0   883050.0
#             Apples                   2002.0   534450.0
#             Apricots                 2002.0  2562448.0
#             Barley                   2002.0  7590000.0
#             Eggs, hen, in shell      2002.0   836500.0
# ...                                     ...        ...
# Sri Lanka   Sweet potatoes           2002.0   636913.0
#             Tea                      2002.0  6767300.0
#             Tobacco, unmanufactured  2002.0  2065092.0
#             Tomatoes                 2002.0  1433915.0
#             Vegetables, fresh nes    2002.0  1528660.0
#
# [410 rows x 2 columns]

# %%
agri_new.loc[:, ["Area", "Year", "Item"]].head(22)
# Out:
#            Area  Year                 Item
# 0   Afghanistan  2002  Almonds, with shell
# 1   Afghanistan  2003  Almonds, with shell
# 2   Afghanistan  2004  Almonds, with shell
# 3   Afghanistan  2005  Almonds, with shell
# 4   Afghanistan  2006  Almonds, with shell
# 5   Afghanistan  2007  Almonds, with shell
# 6   Afghanistan  2008  Almonds, with shell
# 7   Afghanistan  2009  Almonds, with shell
# 8   Afghanistan  2010  Almonds, with shell
# 9   Afghanistan  2011  Almonds, with shell
# 10  Afghanistan  2012  Almonds, with shell
# 11  Afghanistan  2013  Almonds, with shell
# 12  Afghanistan  2014  Almonds, with shell
# 13  Afghanistan  2015  Almonds, with shell
# 14  Afghanistan  2016  Almonds, with shell
# 15  Afghanistan  2017  Almonds, with shell
# 16  Afghanistan  2018  Almonds, with shell
# 17  Afghanistan  2019  Almonds, with shell
# 18  Afghanistan  2020  Almonds, with shell
# 19  Afghanistan  2002               Apples
# 20  Afghanistan  2003               Apples
# ...

# %%
agri_new.loc[0:5, ["Item", "Area"]]
# Out:
#                   Item         Area
# 0  Almonds, with shell  Afghanistan
# 1  Almonds, with shell  Afghanistan
# 2  Almonds, with shell  Afghanistan
# 3  Almonds, with shell  Afghanistan
# 4  Almonds, with shell  Afghanistan
# 5  Almonds, with shell  Afghanistan

# %%
agri_new[agri_new["Value"]<=7500].groupby(["Area", "Item"]).mean()
# Out:
#                                                                 Year  \
# Area                       Item
# Bangladesh                 Barley                        2019.500000
#                            Oilseeds nes                  2009.000000
# Bhutan                     Barley                        2003.000000
#                            Carrots and turnips           2006.500000
#                            Cauliflowers and broccoli     2003.500000
#                            Garlic                        2004.000000
#                            Meat indigenous, buffalo      2011.000000
#                            Meat indigenous, sheep        2016.666667
#                            Meat, buffalo                 2010.555556
#                            Meat, sheep                   2016.666667
#                            Milk, whole fresh buffalo     2008.000000
#                            Mustard seed                  2018.000000
# ...

# %%
afg=agri_new[agri_new["Area"]=="Afghanistan"].groupby(["Year", "Item"]).mean()

# %%
afg
# Out:
#                                Value
# Year Item
# 2002 Almonds, with shell    883050.0
#      Apples                 534450.0
#      Apricots              2562448.0
#      Barley                7590000.0
#      Eggs, hen, in shell    836500.0
# ...                              ...
# 2020 Rice, paddy          20022826.0
#      Walnuts, with shell    730403.0
#      Watermelons           9416309.0
#      Wheat                86957637.0
#      Wool, greasy          1108797.0
#
# [361 rows x 1 columns]

# %%
afg.to_csv("afg.csv")

# %%
afg.value_counts("Value")
afg.groupby(['Value', "Year"]).mean()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
pak=pd.read_csv("pak_data.csv")

# %%
grp=pak[pak["Item"]=="Apples"].groupby(["Year", "Item"]).mean()
grp
# Out:
#                   Value
# Year Item
# 2002 Apples   5874325.0
# 2003 Apples  12073081.0
# 2004 Apples  12802704.0
# 2005 Apples  12995584.0
# 2006 Apples  13240720.0
# 2007 Apples  17663000.0
# 2008 Apples  18524604.0
# 2009 Apples  16486200.0
# 2010 Apples  25241040.0
# 2011 Apples  33893929.0
# 2012 Apples  31451495.0
# 2013 Apples  38143786.0
# 2014 Apples  40969971.0
# 2015 Apples  41267453.0
# 2016 Apples  47690238.0
# 2017 Apples  42452270.0
# 2018 Apples  43257621.0
# 2019 Apples  34577267.0
# 2020 Apples  30842002.0

# %%
two=pak[pak['Year']<=2003].groupby(["Item", "Value"]).mean()
two
# Out:
#                                    Year
# Item                Value
# Almonds, with shell 1302210.0    2002.0
#                     3206763.0    2003.0
# Apples              5874325.0    2002.0
#                     12073081.0   2003.0
# Apricots            2399450.0    2002.0
# ...                                 ...
# Walnuts, with shell 588003.0     2002.0
# Wheat               160848863.0  2002.0
#                     175527195.0  2003.0
# Wool, greasy        1358079.0    2002.0
#                     1418838.0    2003.0
#
# [94 rows x 1 columns]

# %%
two.loc["Sugar cane"]
# Out:
#               Year
# Value
# 28786857.0  2003.0
# 29257334.0  2002.0

# %%
two.loc["Wheat"]
# Out:
#                Year
# Value
# 160848863.0  2002.0
# 175527195.0  2003.0

# %%
agri.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code (FAO)      int64
# Area                object
# Element Code         int64
# Element             object
# Item Code (FAO)      int64
# Item                object
# Year Code            int64
# Year                 int64
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object

# %%
agri["Year"]= agri["Year"].astype("str")

# %%
agri.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code (FAO)      int64
# Area                object
# Element Code         int64
# Element             object
# Item Code (FAO)      int64
# Item                object
# Year Code            int64
# Year                object
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object
